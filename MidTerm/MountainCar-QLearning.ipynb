# %%
#importing the dependencies

import gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#exploring Mountain Car environment

env_name = 'MountainCar-v0'
env = gym.make(env_name)

n_states = 40  # number of states
episodes = 10 # number of episodes

learning_rates = [1.5, 1, 0.5, 0.05]
gamma_arr = [0.99, 0.95]

#initial_lr = 1.0 # initial learning rate
min_lr = 0.005 # minimum learning rate
#gamma = 0.99 # discount factor
max_steps = 300
epsilon = 0.05

env = env.unwrapped
env.seed(0)         #setting environment seed to reproduce same result
np.random.seed(0)   #setting numpy random number generation seed to reproduce same random numbers

def discretization(env, obs): 
    env_low = env.observation_space.low
    env_high = env.observation_space.high
    
    env_den = (env_high - env_low) / n_states
    pos_den = env_den[0]
    vel_den = env_den[1]
    
    pos_high = env_high[0]
    pos_low = env_low[0]
    vel_high = env_high[1]
    vel_low = env_low[1]
    
    pos_scaled = int((obs[0] - pos_low)/pos_den)  #converts to an integer value
    vel_scaled = int((obs[1] - vel_low)/vel_den)  #converts to an integer value
    
    return pos_scaled,vel_scaled

#Q table
#rows are states but here state is 2-D pos,vel
#columns are actions
#therefore, Q- table would be 3-D
reward_log = []
steps_log = []

df_max = pd.DataFrame([])
df_min = pd.DataFrame([])

for l_rate in learning_rates:
    for g in gamma_arr:
        reward_log = []
        steps_log = []
        initial_lr = l_rate
        gamma = g
        q_table = np.zeros((n_states,n_states,env.action_space.n))
        total_steps = 0
        
        print("Learning Rate {} and Gamma {}".format(initial_lr, gamma))
        
        for episode in range(episodes):
              obs = env.reset()
              total_reward = 0
              # decreasing learning rate alpha over time
              alpha = max(min_lr,initial_lr*(gamma**(episode//100)))
              
              steps = 0
              while True:
                  #env.render()
                  pos,vel = discretization(env,obs)

                  #action for the current state using epsilon greedy
                  if np.random.uniform(low=0,high=1) < epsilon:
                        a = np.random.choice(env.action_space.n)
                  else:
                        a = np.argmax(q_table[pos][vel])
                  obs,reward,terminate,_ = env.step(a) 
                  total_reward += abs(obs[0]+0.5)

                  #q-table update
                  pos_,vel_ = discretization(env,obs)
                  q_table[pos][vel][a] = (1-alpha)*q_table[pos][vel][a] + alpha*(reward+gamma*np.max(q_table[pos_][vel_]))
                  steps+=1
                  if terminate:
                        break
              print("Episode {} completed with total reward {} in {} steps".format(episode+1,total_reward,steps)) 
              reward_log.append(total_reward)
              #steps_log.append(steps)


        plt.plot(reward_log, label='Reward')
        #plt.plot(steps_log, label='Steps')
        plt.legend(loc='best')
        plt.grid()
        plt.show()
        

        df_max = df_max.append(pd.DataFrame({'Learning Rate': [alpha], 'Gamma': [gamma], 'Max Reward': [max(reward_log)]}))
        df_min = df_min.append(pd.DataFrame({'Learning Rate': [alpha], 'Gamma': [gamma], 'Min Reward': [min(reward_log)]}))


#while True: #to hold the render at the last step when Car passes the flag
 #     env.render()
# Out:
# Learning Rate 1.5 and Gamma 0.99
# Episode 1 completed with total reward 9753.475320143632 in 30352 steps
# Episode 2 completed with total reward 1444.6692438963023 in 9698 steps
# Episode 3 completed with total reward 1258.600224156571 in 4361 steps
# Episode 4 completed with total reward 585.6765054981906 in 2638 steps
# Episode 5 completed with total reward 1195.285513646124 in 3234 steps
# Episode 6 completed with total reward 2707.2391607133704 in 10866 steps
# Episode 7 completed with total reward 1845.1873743431083 in 7013 steps
# Episode 8 completed with total reward 608.4092763434844 in 1735 steps
# Episode 9 completed with total reward 355.1640909780762 in 1261 steps
# Episode 10 completed with total reward 3930.1468711908333 in 12483 steps
# Learning Rate 1.5 and Gamma 0.95
# Episode 1 completed with total reward 12753.738224378862 in 50056 steps
# Episode 2 completed with total reward 981.3039977769114 in 2399 steps
# Episode 3 completed with total reward 537.9990346029143 in 2172 steps
# Episode 4 completed with total reward 5565.646085766817 in 18023 steps
# Episode 5 completed with total reward 453.5332983412383 in 1263 steps
# Episode 6 completed with total reward 878.1906384467763 in 5997 steps
# Episode 7 completed with total reward 3525.1751198489815 in 12022 steps
# Episode 8 completed with total reward 556.5963186595684 in 1505 steps
# Episode 9 completed with total reward 446.5670418929488 in 1538 steps
# Episode 10 completed with total reward 1749.6542467808558 in 6008 steps
# Learning Rate 1 and Gamma 0.99
# Episode 1 completed with total reward 11392.391986844907 in 35118 steps
# Episode 2 completed with total reward 4485.037748666286 in 15290 steps
# Episode 3 completed with total reward 622.9458790945041 in 1907 steps
# Episode 4 completed with total reward 471.6304014731035 in 1954 steps
# Episode 5 completed with total reward 389.40748653982166 in 1896 steps
# Episode 6 completed with total reward 116.17045631494659 in 775 steps
# Episode 7 completed with total reward 204.4573692670571 in 853 steps
# Episode 8 completed with total reward 195.78581384709454 in 735 steps
# Episode 9 completed with total reward 178.32490814371255 in 696 steps
# Episode 10 completed with total reward 111.02303818425737 in 415 steps
# Learning Rate 1 and Gamma 0.95
# Episode 1 completed with total reward 8417.938701806035 in 27628 steps
# Episode 2 completed with total reward 525.3905186779707 in 2295 steps
# Episode 3 completed with total reward 992.2901894099839 in 2733 steps
# Episode 4 completed with total reward 857.1573766980983 in 2782 steps
# Episode 5 completed with total reward 1305.5309937328213 in 3740 steps
# Episode 6 completed with total reward 2260.2453530284865 in 6384 steps
# Episode 7 completed with total reward 759.3178032293677 in 2466 steps
# Episode 8 completed with total reward 200.95721074916574 in 973 steps
# Episode 9 completed with total reward 2148.2043636978105 in 6042 steps
# Episode 10 completed with total reward 4053.0919444539254 in 12401 steps
# Learning Rate 0.5 and Gamma 0.99
# Episode 1 completed with total reward 3777.0260114335088 in 10449 steps
# Episode 2 completed with total reward 899.4411754253317 in 3833 steps
# Episode 3 completed with total reward 401.737951264634 in 1423 steps
# Episode 4 completed with total reward 523.3758370617776 in 2623 steps
# Episode 5 completed with total reward 558.6743106646298 in 2086 steps
# Episode 6 completed with total reward 1131.0518913017982 in 3206 steps
# Episode 7 completed with total reward 501.55584992215245 in 1719 steps
# Episode 8 completed with total reward 276.7032762586516 in 1179 steps
# Episode 9 completed with total reward 430.72002806746997 in 1740 steps
# Episode 10 completed with total reward 160.65861740307525 in 496 steps
# Learning Rate 0.5 and Gamma 0.95
# Episode 1 completed with total reward 5095.37067028911 in 16241 steps
# Episode 2 completed with total reward 417.765649236992 in 2571 steps
# Episode 3 completed with total reward 461.1346546129437 in 1557 steps
# Episode 4 completed with total reward 217.1423240202295 in 944 steps
# Episode 5 completed with total reward 601.3056464282042 in 1912 steps
# Episode 6 completed with total reward 789.1682004583008 in 2346 steps
# Episode 7 completed with total reward 246.15462653337198 in 950 steps
# Episode 8 completed with total reward 219.10279917023593 in 868 steps
# Episode 9 completed with total reward 504.7277837113592 in 1401 steps
# Episode 10 completed with total reward 323.59682768926774 in 986 steps
# Learning Rate 0.05 and Gamma 0.99
# Episode 1 completed with total reward 14484.330282145494 in 47097 steps
# Episode 2 completed with total reward 1494.552128888793 in 5699 steps
# Episode 3 completed with total reward 4301.352221419945 in 14296 steps
# Episode 4 completed with total reward 962.5894598915779 in 4214 steps
# Episode 5 completed with total reward 2518.1050483908534 in 7995 steps
# Episode 6 completed with total reward 2173.103785598033 in 6652 steps
# Episode 7 completed with total reward 892.625805101607 in 3405 steps
# Episode 8 completed with total reward 727.5323626350984 in 2667 steps
# Episode 9 completed with total reward 2335.9824765692247 in 6672 steps
# Episode 10 completed with total reward 2161.900020413806 in 6895 steps
# Learning Rate 0.05 and Gamma 0.95
# Episode 1 completed with total reward 11170.83070842672 in 36716 steps
# Episode 2 completed with total reward 4112.9720779518475 in 13209 steps
# Episode 3 completed with total reward 2999.773573013703 in 10218 steps
# Episode 4 completed with total reward 436.8252861767394 in 2141 steps
# Episode 5 completed with total reward 2115.1816962246694 in 7273 steps
# Episode 6 completed with total reward 2546.6924240281633 in 7599 steps
# Episode 7 completed with total reward 1869.249252638269 in 6096 steps
# Episode 8 completed with total reward 2763.957592666668 in 9028 steps
# Episode 9 completed with total reward 1017.5764988626167 in 3352 steps
# Episode 10 completed with total reward 2529.057516632638 in 7125 steps

# %%
df_max.head(10)
# Out:
#    Learning Rate  Gamma    Max Reward
# 0           1.50   0.99   9753.475320
# 0           1.50   0.95  12753.738224
# 0           1.00   0.99  11392.391987
# 0           1.00   0.95   8417.938702
# 0           0.50   0.99   3777.026011
# 0           0.50   0.95   5095.370670
# 0           0.05   0.99  14484.330282
# 0           0.05   0.95  11170.830708

# %%
df_min.head(10)
# Out:
#    Learning Rate  Gamma  Min Reward
# 0           1.50   0.99  355.164091
# 0           1.50   0.95  446.567042
# 0           1.00   0.99  111.023038
# 0           1.00   0.95  200.957211
# 0           0.50   0.99  160.658617
# 0           0.50   0.95  217.142324
# 0           0.05   0.99  727.532363
# 0           0.05   0.95  436.825286
